# %%
#bai 1
n,s=abs(int(input())),0
while n>0:
    s+=n%10
    n//=10
#print(len(str(abs(int(input())))))
print(s)
# Out:
# 15

# %%
#bai 2
n=int(input())
print(n*(n+1)/2)
# Out:
# 3.0

# %%
#bai 3
n,a,k,c = int(input()),list(map(int, input().split())),int(input()),0
for i in range(n):
    for j in range(i + 1, n):
        if a[i] + a[j] == k:
            c += 1
print(c)
# Out:
# 2
