# %%
f = open('filename.txt', 'w')
f.close()

# %%
f = open('filename.txt', 'r')
print(f.name)
print(f.mode)
print(f.closed)

# %%
f = open('filename.txt', 'w')
f.write(input("Enter your name:"))
f.close()

# %%
print('abc\ndef')
print(r'abc\ndef')

# %%
f = open('filename.txt', 'r')
print(f.read())
f.close()
# Out:
# abcxyz

# %%
with open('filename.txt', 'r') as f:
    print(f.read())
with open('name.txt', 'a') as f:
    print(f.write(input("What's your name? ")))
